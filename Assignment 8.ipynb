# %%
a=15
if(a>5):
  print("hello")
# Out:
# hello

# %%
a=1
if(a>5):
  print("hello")
else:
  print("hi")
# Out:
# hi

# %%
n=10
if(n%2 ==0 ):
  print("even")
else:
  print("odd")
# Out:
# even

# %%
n=15
if((n%2==0 and n%3==0) or n%5==0 ):
  print("number is divisible")
else:
  print("numbet is not divisible")
# Out:
# number is divisible

# %%
ch='a'
if(ch=="a"or ch=="e"):
  print("vowel")
# Out:
# vowel

# %%
n='p'
if(n in "aeiou"):
  print("vowel")
else:
  print("not vowel")
# Out:
# not vowel

# %%
n='p'
if(n not in "aeiou"):
  print("consonant")
else:
  print("not consonant")
# Out:
# consonant

# %%
n='p'
if(n!="a" or n!="e" or n!="i" or n!="o" or n!="u"):
  print("consonant")
else:
  print("not consonant")
# Out:
# consonant

# %%
x=  input("enter number : ")
print(x,type(x))
# Out:
# enter number : 45
# 45 <class 'str'>

# %%
x=int(input("enter number : "))
print(x,type(x))
x+54
# Out:
# enter number : 67
# 67 <class 'int'>
# 121

# %%
x=int(input("enter number : "))
print(x,type(x))
# Out:
# enter number : 654
# 654 <class 'int'>

# %%
n=int(input("enter a number : "))
if((n%2==0 and  n%6!=0) ):
  print("even number is not divisible by 6")
else:
  print("odd")
# Out:
# enter a number : 22
# even number is not divisible by 6

# %%
x=3
if(x==2):
  print("number is 2")
elif(x==3):
  print("number is 3")
else:
  print("number is not 2 or 3")
# Out:
# number is 3

# %%
x=16
if(x%2==0 and x%3==0):
  print("number is divided by 6")
elif(x%2==0 and x%8==0):
  print("number is divided by both 2 and 8")
else:
  print("number is not divided")
# Out:
# number is divided by both 2 and 8

# %%
age=int(input("enter age : "))
if(age>60):
  print("senior citizon")
elif(age>35):
  print("mature")
elif(age>24):
  print("young")
elif(age>18):
  print("adult")
else:
  print("child")
# Out:
# enter age : 45
# mature

# %%
num=8
if((num%2==0 and  num==6)):
  print("number is even is eqaul to 6")
elif(num%2==0):
  print("number is just even")
else:
  print("odd")
# Out:
# number is just even

# %%
num =6
if(num%2==0):
  print("number is just even")
  if(num==6):
    print("number is even and equal to 6")
  else:
     print("number is just even")
else:
  print("odd")
# Out:
# number is just even
# number is even and equal to 6

# %%
num=20
if(num%3==0):
  if(num%2==0 ):
    print("number is divided by  2 and 3")
  else:
    print("number is divided by 3")
else:
  print("not divided by 3 and 6")
# Out:
# not divided by 3 and 6

# %%
company="regex"
print(company[2])
# Out:
# g

# %%
company="regex"
print(company[-2])
# Out:
# e

# %%
company="regex"
print(company[2:])
# Out:
# gex

# %%
company="regex software"
print(company[0:4])
# Out:
# rege

# %%
company="rajasthan"
print(company[0:4])
# Out:
# raja

# %%
company="rajasthan"
print(company[2:5])
# Out:
# jas

# %%
company="rajasthan"
print(company[:5])
# Out:
# rajas

# %%
company="rajasthan"
print(company[0:5:2])
# Out:
# rjs

# %%
company="rajasthan"
print(company[2:5:2])
# Out:
# js

# %%
company="rajasthan"
print(company[2:7:3])
# Out:
# jt

# %%
company="rajasthan"
print(company[0:4:-1])

# %%
state="rajasthan"
state[3: :-1]
# Out:
# 'ajar'
